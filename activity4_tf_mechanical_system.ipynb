# %%
pip install control
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: control in c:\users\jeric\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (0.10.2)
# Requirement already satisfied: numpy>=1.23 in c:\users\jeric\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from control) (2.3.5)
# Requirement already satisfied: scipy>=1.8 in c:\users\jeric\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from control) (1.17.0)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\jeric\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from control) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jeric\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.6->control) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\jeric\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.6->control) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jeric\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.6->control) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jeric\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.6->control) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\jeric\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.6->control) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\jeric\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.6->control) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\jeric\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.6->control) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jeric\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.6->control) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\jeric\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->control) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\jeric\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import control as ctrl
import matplotlib.pyplot as plt

# %% [markdown]
# # Problem 1
# # M = 1, B1 = 1, B2 = 1, K1 = 1, K2 = 1

# %%
num1 = [1]
den1 = [1, 2, 2]

system1 = ctrl.TransferFunction(num1, den1)

print("Problem 1 Transfer Function:")
print(system1)
# Out:
# Problem 1 Transfer Function:
# <TransferFunction>: sys[0]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#         1
#   -------------
#   s^2 + 2 s + 2

# %%
poles1 = ctrl.poles(system1)
zeros1 = ctrl.zeros(system1)

print("Problem 1 Poles:", poles1)
print("Problem 1 Zeros:", zeros1)
# Out:
# Problem 1 Poles: [-1.+1.j -1.-1.j]
# Problem 1 Zeros: []

# %%
plt.figure()
ctrl.pzmap(system1, grid=True)
plt.title("Pole-Zero Map – Problem 1")
plt.show()

# %% [markdown]
# # Problem 2
# # M = 1, B1 = 1, B2 = 1, K1 = 1

# %%
num2 = [1]
den2 = [1, 2, 1]

system2 = ctrl.TransferFunction(num2, den2)

print("\nProblem 2 Transfer Function:")
print(system2)
# Out:
# Problem 2 Transfer Function:
# <TransferFunction>: sys[1]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#         1
#   -------------
#   s^2 + 2 s + 1

# %%
poles2 = ctrl.poles(system2)
zeros2 = ctrl.zeros(system2)

print("Problem 2 Poles:", poles2)
print("Problem 2 Zeros:", zeros2)
# Out:
# Problem 2 Poles: [-1.+0.j -1.+0.j]
# Problem 2 Zeros: []

# %%
plt.figure()
ctrl.pzmap(system2, grid=True)
plt.title("Pole-Zero Map – Problem 2")
plt.show()
